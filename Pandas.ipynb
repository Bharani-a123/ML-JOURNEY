# %% [markdown]
# <a href="https://colab.research.google.com/github/Bharani-a123/ML-JOURNEY/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive

drive.mount('/content/drive')
df=pd.read_csv("/content/drive/MyDrive/AER_credit_card_data.csv")
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#   card  reports       age  income     share  expenditure owner selfemp  \
# 0  yes        0  37.66667  4.5200  0.033270   124.983300   yes      no
# 1  yes        0  33.25000  2.4200  0.005217     9.854167    no      no
# 2  yes        0  33.66667  4.5000  0.004156    15.000000   yes      no
# 3  yes        0  30.50000  2.5400  0.065214   137.869200    no      no
# 4  yes        0  32.16667  9.7867  0.067051   546.503300   yes      no
#
#    dependents  months  majorcards  active
# 0           3      54           1      12
# 1           3      34           1      13
# 2           4      58           1       5
# 3           0      25           1       7
# 4           2      64           1       5

# %% [markdown]
# ## Handling MIssing **Data**

# %%
d=pd.read_csv("/content/employees.csv")

# %%
Missing =  d.isnull()
display(Missing)
# Out:
#      First Name  Gender  Start Date  Last Login Time  Salary  Bonus %  \
# 0         False   False       False            False   False    False
# 1         False   False       False            False   False    False
# 2         False   False       False            False   False    False
# 3         False   False       False            False   False    False
# 4         False   False       False            False   False    False
# ..          ...     ...         ...              ...     ...      ...
# 995       False    True       False            False   False    False
# 996       False   False       False            False   False    False
# 997       False   False       False            False   False    False
# 998       False   False       False            False   False    False
# 999       False   False       False            False   False    False
#
#      Senior Management   Team
# 0                False  False
# 1                False   True
# 2                False  False
# ...

# %%
miss = d["Salary"].isnull().sum()
display(miss)
# Out:
# np.int64(0)

# %%
  #isna() function
  miss = d["Gender"].isna()
  display(miss)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Gender, Length: 1000, dtype: bool

# %%
#fillna function is used to fill the missing values

d.fillna(0)
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry       0  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                     0
# ...

# %%
d.fillna(method="pad") #used to fill previous elemt by pad or ffill
# Out:
# /tmp/ipython-input-3837117050.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   d.fillna(method="pad") #used to fill previous elemt by pad or ffill
# /tmp/ipython-input-3837117050.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   d.fillna(method="pad") #used to fill previous elemt by pad or ffill
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# ...

# %%
d.fillna(method="bfill") #used to fill next elemt of null values
# Out:
# /tmp/ipython-input-4127947420.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   d.fillna(method="bfill") #used to fill next elemt of null values
# /tmp/ipython-input-4127947420.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   d.fillna(method="bfill") #used to fill next elemt of null values
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# ...

# %%
#replace the values with what we expect using fillna
d["Gender"].fillna("NO GENDER")
# Out:
# 0           Male
# 1           Male
# 2         Female
# 3           Male
# 4           Male
#          ...
# 995    NO GENDER
# 996         Male
# 997         Male
# 998         Male
# 999         Male
# Name: Gender, Length: 1000, dtype: object

# %% [markdown]
# Fill missing values using replace function

# %%
d.replace(to_replace=np.nan,value=88)
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry      88  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                    88
# ...

# %%
#interpolate function (is used like this )


import pandas as pd
s = pd.Series([1, None, 3, None, 7])
s.interpolate()
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    5.0
# 4    7.0
# dtype: float64

# %%
#dropna function is used drop rows of null values

d.dropna()
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 2        Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male  1/24/1998         4:47 PM  101004    1.389
# 5       Dennis    Male  4/18/1987         1:35 AM  115163   10.125
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male  6/21/2013         5:47 PM   98874    4.479
# 996    Phillip    Male  1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 2               False               Finance
# ...

# %%
d.dropna(how="all")
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
d.dropna(how="any")
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 2        Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male  1/24/1998         4:47 PM  101004    1.389
# 5       Dennis    Male  4/18/1987         1:35 AM  115163   10.125
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male  6/21/2013         5:47 PM   98874    4.479
# 996    Phillip    Male  1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 2               False               Finance
# ...

# %%
miss=df.isnull().sum()
display(miss)
# Out:
# card           0
# reports        0
# age            0
# income         0
# share          0
# expenditure    0
# owner          0
# selfemp        0
# dependents     0
# months         0
# majorcards     0
# active         0
# dtype: int64

# %% [markdown]
# REMOVING DUPLICATES
#
# **bold text**

# %%
d.drop_duplicates()
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
d.drop_duplicates(subset=["Gender"],inplace=True)
display(d)
# Out:
#    First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0     Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 2       Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 20       Lois     NaN  4/22/1995         7:18 PM   64714    4.934
#
#    Senior Management       Team
# 0               True  Marketing
# 2              False    Finance
# 20              True      Legal

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   card         1319 non-null   object
#  1   reports      1319 non-null   int64
#  2   age          1319 non-null   float64
#  3   income       1319 non-null   float64
#  4   share        1319 non-null   float64
#  5   expenditure  1319 non-null   float64
#  6   owner        1319 non-null   object
#  7   selfemp      1319 non-null   object
#  8   dependents   1319 non-null   int64
#  9   months       1319 non-null   int64
#  10  majorcards   1319 non-null   int64
#  11  active       1319 non-null   int64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 123.8+ KB

# %%
df.describe()
# Out:
#            reports          age       income        share  expenditure  \
# count  1319.000000  1319.000000  1319.000000  1319.000000  1319.000000
# mean      0.456406    33.213103     3.365376     0.068732   185.057071
# std       1.345267    10.142783     1.693902     0.094656   272.218917
# min       0.000000     0.166667     0.210000     0.000109     0.000000
# 25%       0.000000    25.416670     2.243750     0.002316     4.583333
# 50%       0.000000    31.250000     2.900000     0.038827   101.298300
# 75%       0.000000    39.416670     4.000000     0.093617   249.035800
# max      14.000000    83.500000    13.500000     0.906320  3099.505000
#
#         dependents       months   majorcards       active
# count  1319.000000  1319.000000  1319.000000  1319.000000
# mean      0.993935    55.267627     0.817286     6.996967
# std       1.247745    66.271746     0.386579     6.305812
# min       0.000000     0.000000     0.000000     0.000000
# ...

# %%
dff = df.groupby('age')['income'].sum()
display(dff)
# Out:
# age
# 0.166667     3.2400
# 0.500000     6.7500
# 0.583333     6.5000
# 0.750000     4.6000
# 18.166670    2.8200
#               ...
# 69.750000    1.8000
# 71.833340    7.7010
# 74.166660    2.8065
# 80.166660    1.5000
# 83.500000    2.8725
# Name: income, Length: 418, dtype: float64

# %%
import pandas as pd
df = pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv")

grouping = df.groupby(['Team', 'Position'])
print(grouping.first())
# Out:
#                                          Name  Number   Age Height  Weight  \
# Team               Position
# Atlanta Hawks      C               Al Horford    15.0  30.0   6-10   245.0
#                    PF          Kris Humphries    43.0  31.0    6-9   235.0
#                    PG         Dennis Schroder    17.0  22.0    6-1   172.0
#                    SF           Kent Bazemore    24.0  26.0    6-5   201.0
#                    SG        Tim Hardaway Jr.    10.0  24.0    6-6   205.0
# ...                                       ...     ...   ...    ...     ...
# Washington Wizards C            Marcin Gortat    13.0  32.0   6-11   240.0
#                    PF             Drew Gooden    90.0  34.0   6-10   250.0
#                    PG          Ramon Sessions     7.0  30.0    6-3   190.0
#                    SF            Jared Dudley     1.0  30.0    6-7   225.0
#                    SG           Alan Anderson     6.0  33.0    6-6   220.0
#
# ...
